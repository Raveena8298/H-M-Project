# %%
# !pip install WordCloud
# Out:
# Collecting WordCloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-macosx_10_9_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 2.0 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib in /Users/banu/opt/anaconda3/lib/python3.9/site-packages (from WordCloud) (3.5.1)
# Requirement already satisfied: numpy>=1.6.1 in /Users/banu/opt/anaconda3/lib/python3.9/site-packages (from WordCloud) (1.21.5)
# Requirement already satisfied: pillow in /Users/banu/opt/anaconda3/lib/python3.9/site-packages (from WordCloud) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/banu/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->WordCloud) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/banu/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->WordCloud) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/banu/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->WordCloud) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/banu/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->WordCloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/banu/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->WordCloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/banu/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->WordCloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in /Users/banu/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.16.0)
# Installing collected packages: WordCloud
# Successfully installed WordCloud-1.8.2.2

# %%
# Imports
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import nltk

from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer 
from wordcloud import WordCloud
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# %matplotlib inline
porter_stemmer = PorterStemmer()
wordnet_lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to /Users/banu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/banu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/banu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/banu/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df = pd.read_csv('articles.csv')

# %%
df.head(2)
# Out:
#    article_id  product_code  prod_name  product_type_no product_type_name  \
# 0   108775015        108775  Strap top              253          Vest top
# 1   108775044        108775  Strap top              253          Vest top
#
#    product_group_name  graphical_appearance_no graphical_appearance_name  \
# 0  Garment Upper body                  1010016                     Solid
# 1  Garment Upper body                  1010016                     Solid
#
#    colour_group_code colour_group_name  ...  department_name index_code  \
# 0                  9             Black  ...     Jersey Basic          A
# 1                 10             White  ...     Jersey Basic          A
#
#    index_name index_group_no  index_group_name section_no  \
# 0  Ladieswear              1        Ladieswear         16
# 1  Ladieswear              1        Ladieswear         16
#
#              section_name garment_group_no  garment_group_name  \
# 0  Womens Everyday Basics             1002        Jersey Basic
# 1  Womens Everyday Basics             1002        Jersey Basic
#
#                                detail_desc
# 0  Jersey top with narrow shoulder straps.
# 1  Jersey top with narrow shoulder straps.
#
# [2 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['article_id', 'product_code', 'prod_name', 'product_type_no',
#        'product_type_name', 'product_group_name', 'graphical_appearance_no',
#        'graphical_appearance_name', 'colour_group_code', 'colour_group_name',
#        'perceived_colour_value_id', 'perceived_colour_value_name',
#        'perceived_colour_master_id', 'perceived_colour_master_name',
#        'department_no', 'department_name', 'index_code', 'index_name',
#        'index_group_no', 'index_group_name', 'section_no', 'section_name',
#        'garment_group_no', 'garment_group_name', 'detail_desc'],
#       dtype='object')

# %%
df.shape
# Out:
# (105542, 25)

# %%
df.describe()
# Out:
#          article_id   product_code  product_type_no  graphical_appearance_no  \
# count  1.055420e+05  105542.000000    105542.000000             1.055420e+05
# mean   6.984246e+08  698424.563378       234.861875             1.009515e+06
# std    1.284624e+08  128462.384432        75.049308             2.241359e+04
# min    1.087750e+08  108775.000000        -1.000000            -1.000000e+00
# 25%    6.169925e+08  616992.500000       252.000000             1.010008e+06
# 50%    7.022130e+08  702213.000000       259.000000             1.010016e+06
# 75%    7.967030e+08  796703.000000       272.000000             1.010016e+06
# max    9.594610e+08  959461.000000       762.000000             1.010029e+06
#
#        colour_group_code  perceived_colour_value_id  \
# count      105542.000000              105542.000000
# mean           32.233822                   3.206183
# std            28.086154                   1.563839
# min            -1.000000                  -1.000000
# 25%             9.000000                   2.000000
# 50%            14.000000                   4.000000
# 75%            52.000000                   4.000000
# max            93.000000                   7.000000
#
#        perceived_colour_master_id  department_no  index_group_no  \
# count               105542.000000  105542.000000   105542.000000
# mean                     7.807972    4532.777833        3.171534
# std                      5.376727    2712.692011        4.353234
# min                     -1.000000    1201.000000        1.000000
# 25%                      4.000000    1676.000000        1.000000
# 50%                      5.000000    4222.000000        2.000000
# 75%                     11.000000    7389.000000        4.000000
# max                     20.000000    9989.000000       26.000000
#
#           section_no  garment_group_no
# count  105542.000000     105542.000000
# mean       42.664219       1010.438290
# std        23.260105          6.731023
# min         2.000000       1001.000000
# 25%        20.000000       1005.000000
# 50%        46.000000       1009.000000
# 75%        61.000000       1017.000000
# max        97.000000       1025.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105542 entries, 0 to 105541
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   article_id                    105542 non-null  int64
#  1   product_code                  105542 non-null  int64
#  2   prod_name                     105542 non-null  object
#  3   product_type_no               105542 non-null  int64
#  4   product_type_name             105542 non-null  object
#  5   product_group_name            105542 non-null  object
#  6   graphical_appearance_no       105542 non-null  int64
#  7   graphical_appearance_name     105542 non-null  object
#  8   colour_group_code             105542 non-null  int64
#  9   colour_group_name             105542 non-null  object
#  10  perceived_colour_value_id     105542 non-null  int64
#  11  perceived_colour_value_name   105542 non-null  object
#  12  perceived_colour_master_id    105542 non-null  int64
#  13  perceived_colour_master_name  105542 non-null  object
#  14  department_no                 105542 non-null  int64
#  15  department_name               105542 non-null  object
#  16  index_code                    105542 non-null  object
#  17  index_name                    105542 non-null  object
#  18  index_group_no                105542 non-null  int64
#  19  index_group_name              105542 non-null  object
#  20  section_no                    105542 non-null  int64
#  21  section_name                  105542 non-null  object
#  22  garment_group_no              105542 non-null  int64
#  23  garment_group_name            105542 non-null  object
#  24  detail_desc                   105126 non-null  object
# dtypes: int64(11), object(14)
# memory usage: 20.1+ MB

# %% [markdown]
# Print all Categorical Columns

# %%
# Categorical Column
print('Categorical Columns\n')
cat_cols = [col for col in df.columns if df[col].dtype == "object"]
cat_cols
# Out:
# Categorical Columns
# ['prod_name',
#  'product_type_name',
#  'product_group_name',
#  'graphical_appearance_name',
#  'colour_group_name',
#  'perceived_colour_value_name',
#  'perceived_colour_master_name',
#  'department_name',
#  'index_code',
#  'index_name',
#  'index_group_name',
#  'section_name',
#  'garment_group_name',
#  'detail_desc']

# %% [markdown]
# Print all Numerical Columns

# %%
# Numerical Columns
print('Numerical Columns\n')
numeric = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
num_cols = [col for col in df.columns if df[col].dtype in numeric]
num_cols
# Out:
# Numerical Columns
# ['article_id',
#  'product_code',
#  'product_type_no',
#  'graphical_appearance_no',
#  'colour_group_code',
#  'perceived_colour_value_id',
#  'perceived_colour_master_id',
#  'department_no',
#  'index_group_no',
#  'section_no',
#  'garment_group_no']

# %% [markdown]
# Although above is list of numeical columns
# but except article_id can not consider other columns as numerical
# they all are categorical but categories are in numerical format

# %%
# article_id 
# product_code 
# prod_name 
# product_type_no
# product_type_name
# product_group_name
# graphical_appearance_name
# colour_group_name
# perceived_colour_value_name
# perceived_colour_master_name
# department_name
# index_name
# index_group_name
# garment_group_name

# %% [markdown]
# Count Unique values in each column

# %%
df.nunique()
# Out:
# article_id                      105542
# product_code                     47224
# prod_name                        45875
# product_type_no                    132
# product_type_name                  131
# product_group_name                  19
# graphical_appearance_no             30
# graphical_appearance_name           30
# colour_group_code                   50
# colour_group_name                   50
# perceived_colour_value_id            8
# perceived_colour_value_name          8
# perceived_colour_master_id          20
# perceived_colour_master_name        20
# department_no                      299
# department_name                    250
# index_code                          10
# index_name                          10
# index_group_no                       5
# index_group_name                     5
# section_no                          57
# section_name                        56
# garment_group_no                    21
# garment_group_name                  21
# detail_desc                      43404
# dtype: int64

# %%
# unique values in numerical columns
df.loc[:,num_cols].nunique()
# Out:
# article_id                    105542
# product_code                   47224
# product_type_no                  132
# graphical_appearance_no           30
# colour_group_code                 50
# perceived_colour_value_id          8
# perceived_colour_master_id        20
# department_no                    299
# index_group_no                     5
# section_no                        57
# garment_group_no                  21
# dtype: int64

# %% [markdown]
# Check if unique values in duplicate columns count to same

# %%
print(df.index_group_no.unique()) # numerical
print(df.index_group_name.unique()) # categorical
# Out:
# [ 1  4  3 26  2]
# ['Ladieswear' 'Baby/Children' 'Menswear' 'Sport' 'Divided']

# %%
print(df.perceived_colour_value_id.unique()) # numerical
print(df.perceived_colour_value_name.unique()) # categorical
# Out:
# [ 4  3  1  2  5  7  6 -1]
# ['Dark' 'Light' 'Dusty Light' 'Medium Dusty' 'Bright' 'Medium' 'Undefined'
#  'Unknown']

# %%
print(df.perceived_colour_master_id.unique())
print(df.perceived_colour_master_name.unique())
# Out:
# [ 5  9 11 12  2  4  6 18  1  3 15 13  7  8 20 19 14 -1 10 16]
# ['Black' 'White' 'Beige' 'Grey' 'Blue' 'Pink' 'Lilac Purple' 'Red' 'Mole'
#  'Orange' 'Metal' 'Brown' 'Turquoise' 'Yellow' 'Khaki green' 'Green'
#  'undefined' 'Unknown' 'Yellowish Green' 'Bluish Green']

# %%
print(df.colour_group_code.unique())
print(df.colour_group_name.unique())
# Out:
# [ 9 10 11 12 13  7 71  6 73  8 52 43 15 31  3  5 51 53 17 72 81 22 19 23
#  50 63 42  2 93 40 82 33  1 32 14 20 91 30 62 41 21 92 61 83 60  4 80 90
#  70 -1]
# ['Black' 'White' 'Off White' 'Light Beige' 'Beige' 'Grey' 'Light Blue'
#  'Light Grey' 'Dark Blue' 'Dark Grey' 'Pink' 'Dark Red' 'Greyish Beige'
#  'Light Orange' 'Silver' 'Gold' 'Light Pink' 'Dark Pink' 'Yellowish Brown'
#  'Blue' 'Light Turquoise' 'Yellow' 'Greenish Khaki' 'Dark Yellow'
#  'Other Pink' 'Dark Purple' 'Red' 'Transparent' 'Dark Green' 'Other Red'
#  'Turquoise' 'Dark Orange' 'Other' 'Orange' 'Dark Beige' 'Other Yellow'
#  'Light Green' 'Other Orange' 'Purple' 'Light Red' 'Light Yellow' 'Green'
#  'Light Purple' 'Dark Turquoise' 'Other Purple' 'Bronze/Copper'
#  'Other Turquoise' 'Other Green' 'Other Blue' 'Unknown']

# %% [markdown]
# Remove unwanted/duplicates columns

# %%
df.columns
# Out:
# Index(['article_id', 'product_code', 'prod_name', 'product_type_no',
#        'product_type_name', 'product_group_name', 'graphical_appearance_no',
#        'graphical_appearance_name', 'colour_group_code', 'colour_group_name',
#        'perceived_colour_value_id', 'perceived_colour_value_name',
#        'perceived_colour_master_id', 'perceived_colour_master_name',
#        'department_no', 'department_name', 'index_code', 'index_name',
#        'index_group_no', 'index_group_name', 'section_no', 'section_name',
#        'garment_group_no', 'garment_group_name', 'detail_desc'],
#       dtype='object')

# %%
# Check length of expected duplicate columns
# If same then they are duplicates else not 
len(df.garment_group_no.unique()) == len(df.garment_group_name.unique())
# Out:
# True

# %%
############
## Remove ##
############

# graphical_appearance_name
# colour_group_name
# perceived_colour_value_name
# perceived_colour_master_name
# index_name
# index_group_name
# garment_group_name

# %%
# Remove all duplicate columns
gg = ['graphical_appearance_no','colour_group_code','perceived_colour_value_id','perceived_colour_master_id','index_code','index_group_no','garment_group_no']
clmns = df.columns
new_clmns = [x for x in clmns if x not in gg]
new_clmns
# Out:
# ['article_id',
#  'product_code',
#  'prod_name',
#  'product_type_no',
#  'product_type_name',
#  'product_group_name',
#  'graphical_appearance_name',
#  'colour_group_name',
#  'perceived_colour_value_name',
#  'perceived_colour_master_name',
#  'department_no',
#  'department_name',
#  'index_name',
#  'index_group_name',
#  'section_no',
#  'section_name',
#  'garment_group_name',
#  'detail_desc']

# %%
print('Length of new columns: ',len(new_clmns))
# Out:
# Length of new columns:  18

# %%
df1 = df.loc[:,new_clmns]
df1
# Out:
#         article_id  product_code               prod_name  product_type_no  \
# 0        108775015        108775               Strap top              253
# 1        108775044        108775               Strap top              253
# 2        108775051        108775           Strap top (1)              253
# 3        110065001        110065       OP T-shirt (Idro)              306
# 4        110065002        110065       OP T-shirt (Idro)              306
# ...            ...           ...                     ...              ...
# 105537   953450001        953450  5pk regular Placement1              302
# 105538   953763001        953763       SPORT Malaga tank              253
# 105539   956217002        956217         Cartwheel dress              265
# 105540   957375001        957375        CLAIRE HAIR CLAW               72
# 105541   959461001        959461            Lounge dress              265
#
#        product_type_name  product_group_name graphical_appearance_name  \
# 0               Vest top  Garment Upper body                     Solid
# 1               Vest top  Garment Upper body                     Solid
# 2               Vest top  Garment Upper body                    Stripe
# 3                    Bra           Underwear                     Solid
# 4                    Bra           Underwear                     Solid
# ...                  ...                 ...                       ...
# 105537             Socks      Socks & Tights           Placement print
# 105538          Vest top  Garment Upper body                     Solid
# 105539             Dress   Garment Full body                     Solid
# 105540         Hair clip         Accessories                     Solid
# 105541             Dress   Garment Full body                     Solid
#
#        colour_group_name perceived_colour_value_name  \
# 0                  Black                        Dark
# 1                  White                       Light
# 2              Off White                 Dusty Light
# 3                  Black                        Dark
# 4                  White                       Light
# ...                  ...                         ...
# 105537             Black                        Dark
# 105538             Black                        Dark
# 105539             Black                        Dark
# 105540             Black                        Dark
# 105541         Off White                 Dusty Light
#
#        perceived_colour_master_name  department_no    department_name  \
# 0                             Black           1676       Jersey Basic
# 1                             White           1676       Jersey Basic
# 2                             White           1676       Jersey Basic
# 3                             Black           1339     Clean Lingerie
# 4                             White           1339     Clean Lingerie
# ...                             ...            ...                ...
# 105537                        Black           7188          Socks Bin
# 105538                        Black           1919             Jersey
# 105539                        Black           1641             Jersey
# 105540                        Black           3946  Small Accessories
# 105541                        White           1641             Jersey
#
#               index_name index_group_name  section_no            section_name  \
# 0             Ladieswear       Ladieswear          16  Womens Everyday Basics
# 1             Ladieswear       Ladieswear          16  Womens Everyday Basics
# 2             Ladieswear       Ladieswear          16  Womens Everyday Basics
# 3       Lingeries/Tights       Ladieswear          61         Womens Lingerie
# 4       Lingeries/Tights       Ladieswear          61         Womens Lingerie
# ...                  ...              ...         ...                     ...
# 105537          Menswear         Menswear          26           Men Underwear
# 105538        Ladieswear       Ladieswear           2                    H&M+
# 105539        Ladieswear       Ladieswear          18            Womens Trend
# 105540           Divided          Divided          52     Divided Accessories
# 105541        Ladieswear       Ladieswear          18            Womens Trend
#
#        garment_group_name                                        detail_desc
# 0            Jersey Basic            Jersey top with narrow shoulder straps.
# 1            Jersey Basic            Jersey top with narrow shoulder straps.
# 2            Jersey Basic            Jersey top with narrow shoulder straps.
# 3       Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
# 4       Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
# ...                   ...                                                ...
# 105537   Socks and Tights  Socks in a fine-knit cotton blend with a small...
# 105538       Jersey Fancy  Loose-fitting sports vest top in ribbed fast-d...
# 105539       Jersey Fancy  Short, A-line dress in jersey with a round nec...
# 105540        Accessories                           Large plastic hair claw.
# 105541       Jersey Fancy  Calf-length dress in ribbed jersey made from a...
#
# [105542 rows x 18 columns]

# %%
df1.shape
# Out:
# (105542, 18)

# %% [markdown]
# Missing values search

# %%
# sum of null values across all dataframe
df.isna().sum().sum()
# Out:
# 416

# %%
# count null values in each column
df.isna().sum()
# detail_desc is only column with null values
# Out:
# article_id                        0
# product_code                      0
# prod_name                         0
# product_type_no                   0
# product_type_name                 0
# product_group_name                0
# graphical_appearance_no           0
# graphical_appearance_name         0
# colour_group_code                 0
# colour_group_name                 0
# perceived_colour_value_id         0
# perceived_colour_value_name       0
# perceived_colour_master_id        0
# perceived_colour_master_name      0
# department_no                     0
# department_name                   0
# index_code                        0
# index_name                        0
# index_group_no                    0
# index_group_name                  0
# section_no                        0
# section_name                      0
# garment_group_no                  0
# garment_group_name                0
# detail_desc                     416
# dtype: int64

# %%
df1.nunique()
# Out:
# article_id                      105542
# product_code                     47224
# prod_name                        45875
# product_type_no                    132
# product_type_name                  131
# product_group_name                  19
# graphical_appearance_name           30
# colour_group_name                   50
# perceived_colour_value_name          8
# perceived_colour_master_name        20
# department_no                      299
# department_name                    250
# index_name                          10
# index_group_name                     5
# section_no                          57
# section_name                        56
# garment_group_name                  21
# detail_desc                      43404
# dtype: int64

# %% [markdown]
# ## Univariate analysis

# %%
def univ_plot(col_name, fig_size =(25,10), rot_tixks = 80, rot_labels = 45, miss = 0, top = 'all'):
  '''
  To plot univariate visualizaitons
  Paramters- fig_size: (figure size in tuple format), column_name: column name,rot_xtixks: rotation of xticks, rot_labels: rotation of labels on the barplot
              miss: number of first entries to miss
  Return: plot the visulizatiopn usiong seaborn
  '''
  
  plt.figure(figsize=fig_size)
  plt.title('Univariate Analysis - '+str(col_name))
  plt.xlabel('Categories')
  plt.ylabel('Count')

  if top =='all':
    dict = df[col_name].value_counts()[miss:].to_dict()
  else:
    dict = df[col_name].value_counts()[miss:int(top)].to_dict()
    
  values =  [int(i) for i in dict.values()]
  ax = sns.barplot(x=list(dict.keys()),y=values)
  plt.xticks(rotation= rot_tixks)

  # To add labels above each bar
  for p, label in zip(ax.patches, values):
      ax.annotate(label, (p.get_x()+0.25, p.get_height()+0.5),rotation = rot_labels)

# %% [markdown]
# garment_group_name

# %%
univ_plot(col_name='garment_group_name',fig_size=(15,10))

# %% [markdown]
# section_name

# %%
univ_plot(col_name='section_name',fig_size=(20,15))

# %% [markdown]
# index_group_name

# %%
univ_plot(col_name='index_group_name',fig_size=(17,10),rot_tixks=0)

# %% [markdown]
# index_name

# %%
univ_plot(col_name='index_name',fig_size=(16,10), rot_tixks=20, top = 5)

# %% [markdown]
# department_name

# %%
univ_plot(col_name='department_name',fig_size=(30,10))

# %%
univ_plot(col_name='department_name',fig_size=(12,10),top = 30)

# %% [markdown]
# perceived_colour_master_name

# %%
univ_plot(col_name='perceived_colour_master_name',fig_size=(12,10),top = 30)

# %%
univ_plot(col_name='perceived_colour_master_name',fig_size=(12,10),top = 5)

# %%
univ_plot(col_name='perceived_colour_master_name',fig_size=(12,10),miss = 15)

# %% [markdown]
# perceived_colour_value_name

# %%
univ_plot(col_name='perceived_colour_value_name',fig_size=(12,10), rot_tixks=20, top=5)

# %%
df1.shape
# Out:
# (105542, 18)

# %% [markdown]
# colour_group_name

# %%
univ_plot(col_name = 'colour_group_name',fig_size = (25,15),rot_tixks = 50,rot_labels = 42)

# %%
univ_plot(col_name = 'colour_group_name',fig_size = (15,10),rot_tixks = 50,rot_labels = 42,top=20)

# %%
univ_plot(col_name = 'colour_group_name',fig_size = (15,10),rot_tixks = 50,rot_labels = 42,miss=20)

# %% [markdown]
# graphical_appearance_name

# %%
univ_plot(col_name = 'graphical_appearance_name',fig_size = (15,10),rot_tixks = 50,rot_labels = 42)

# %%
univ_plot(col_name = 'graphical_appearance_name',fig_size = (15,10),rot_tixks = 20,rot_labels = 42,top=5)

# %%
univ_plot(col_name = 'graphical_appearance_name',fig_size = (15,10),rot_tixks = 50,rot_labels = 42,miss=7)

# %% [markdown]
# product_group_name

# %%
univ_plot(col_name = 'product_group_name',fig_size = (15,10),rot_tixks = 30,rot_labels = 50, top = 8)

# %%
univ_plot(col_name = 'product_group_name',fig_size = (15,10),rot_tixks = 50,rot_labels = 42,miss=9)

# %% [markdown]
# prod_name

# %%
univ_plot(col_name = 'prod_name',fig_size = (15,10),rot_tixks = 80,rot_labels = 42, top=40)

# %% [markdown]
# product_type_name

# %%
univ_plot(col_name = 'product_type_name',fig_size = (15,10),top=30)

# %%
univ_plot(col_name = 'product_type_name',fig_size = (15,10),top=10)

# %% [markdown]
# Ladieswear | Solid | Dark | Black

# %%
df1.product_group_name.unique()
# Out:
# array(['Garment Upper body', 'Underwear', 'Socks & Tights',
#        'Garment Lower body', 'Accessories', 'Items', 'Nightwear',
#        'Unknown', 'Underwear/nightwear', 'Shoes', 'Swimwear',
#        'Garment Full body', 'Cosmetic', 'Interior textile', 'Bags',
#        'Furniture', 'Garment and Shoe care', 'Fun', 'Stationery'],
#       dtype=object)

# %%
df1[(df1['index_group_name'] == 'Ladieswear')].shape
# Out:
# (39737, 18)

# %%
df1[(df1['graphical_appearance_name'] == 'Solid')  & (df1['index_group_name'] == 'Ladieswear')].shape
# Out:
# (23426, 18)

# %%
# How many solids among Ladieswear
(df1[(df1['graphical_appearance_name'] == 'Solid')  & (df1['index_group_name'] == 'Ladieswear')].shape[0]) /(df1[(df1['index_group_name'] == 'Ladieswear')].shape[0])
# Out:
# 0.5895261343332411

# %%
df1[(df1['perceived_colour_value_name'] == 'Dark') & (df1['graphical_appearance_name'] == 'Solid')  & (df1['index_group_name'] == 'Ladieswear')].shape
# Out:
# (10436, 18)

# %%
df1[(df1['product_group_name'] == 'Garment Lower body') & (df1['index_group_name'] == 'Ladieswear')].shape
# Out:
# (5742, 18)

# %%
# How many Lower body and Ladies
(df1[(df1['product_group_name'] == 'Garment Lower body') & (df1['index_group_name'] == 'Ladieswear')].shape[0])/(df1[(df1['index_group_name'] == 'Ladieswear')].shape[0])
# Out:
# 0.1445000880791202

# %%
# How many Upper body and Ladies
(df1[(df1['product_group_name'] == 'Garment Upper body') & (df1['index_group_name'] == 'Ladieswear')].shape[0])/(df1[(df1['index_group_name'] == 'Ladieswear')].shape[0])
# Out:
# 0.3550846817827214

# %% [markdown]
# ## Bivariate analysis

# %%
df.index_group_name.unique()
# Out:
# array(['Ladieswear', 'Baby/Children', 'Menswear', 'Sport', 'Divided'],
#       dtype=object)

# %%
df.index_name.unique()
# Out:
# array(['Ladieswear', 'Lingeries/Tights', 'Baby Sizes 50-98', 'Menswear',
#        'Ladies Accessories', 'Sport', 'Children Sizes 92-140', 'Divided',
#        'Children Sizes 134-170', 'Children Accessories, Swimwear'],
#       dtype=object)

# %%
df1.nunique()
# Out:
# article_id                      105542
# product_code                     47224
# prod_name                        45875
# product_type_no                    132
# product_type_name                  131
# product_group_name                  19
# graphical_appearance_name           30
# colour_group_name                   50
# perceived_colour_value_name          8
# perceived_colour_master_name        20
# department_no                      299
# department_name                    250
# index_name                          10
# index_group_name                     5
# section_no                          57
# section_name                        56
# garment_group_name                  21
# detail_desc                      43404
# dtype: int64

# %%
df.index_group_name.unique()
# Out:
# array(['Ladieswear', 'Baby/Children', 'Menswear', 'Sport', 'Divided'],
#       dtype=object)

# %%
plt.figure(figsize=(20, 10))
ax = sns.histplot(data=df1, y='product_group_name', hue='index_group_name', multiple="stack")
plt.show()

# %%
plt.figure(figsize=(25, 10))
ax = sns.histplot(data=df1, y='garment_group_name', hue='index_group_name', multiple="stack")
plt.show()

# %%
aa = df1.groupby(['garment_group_name', 'index_group_name']).count()
aa.to_csv('grouped.csv')

# %%
plt.figure(figsize=(25, 10))
ax = sns.histplot(data=df1, y='garment_group_name', hue='perceived_colour_value_name', multiple="stack")
plt.show()

# %%
plt.figure(figsize=(20, 10))
ax = sns.histplot(data=df1, y='product_group_name', hue='perceived_colour_value_name', multiple="stack")
plt.show()

# %%
plt.figure(figsize=(15, 5))
ax = sns.histplot(data=df1, y='garment_group_name', hue='perceived_colour_value_name', multiple="stack")
plt.show()

# %%
plt.figure(figsize=(15, 5))
ax = sns.histplot(data = df1, y='garment_group_name', color='orange', hue='index_group_name', multiple="stack")
plt.xlabel('count by garment group')
plt.ylabel('garment group')
plt.show()

# %% [markdown]
# ## Word Clouds

# %%
# df = pd.read_csv('articles.csv')
df = df.dropna()

# %%
# Tokenization
import re
def tokenization(text):
    tokens = re.split(' ',text)
    return tokens

# Remove Stop words
stopwords = nltk.corpus.stopwords.words('english')
def remove_stopwords(text):
    output= [i for i in text if i not in stopwords]
    return output

# Stemming
def stemming(text):
    stem_text = [porter_stemmer.stem(word) for word in text]
    return stem_text

#Lemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
def lemmatizer(text):
    lemm_text = [wordnet_lemmatizer.lemmatize(word) for word in text]
    return lemm_text

# all lowercase
df['detail_desc']=df['detail_desc'].str.lower()

df['detail_desc']= df['detail_desc'].apply(lambda x: tokenization(x))
df['detail_desc']=df['detail_desc'].apply(lambda x: stemming(x))
df['detail_desc']= df['detail_desc'].apply(lambda x:remove_stopwords(x))
df['detail_desc']=df['detail_desc'].apply(lambda x:lemmatizer(x))

# %%
# all daata into one
corpus = nltk.flatten(df['detail_desc'].to_list())

# %%
wordcloud = WordCloud(background_color="white",width=1600, height=800).generate(' '.join(corpus))
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)

# %%
# Word count
pd.value_counts(np.array(corpus))[:10]
# Out:
# cotton    33706
# elast     28800
# top       25642
# soft      24063
# jersey    23023
# rib       22597
# hem.      22381
# front     21170
# button    20539
# sleev     20244
# dtype: int64
